# %%
# %%bash
#
# source activate magenta
#
# INPUT_DIRECTORY=/Users/hyojeongshin/test/data
#
# SEQUENCES_TFRECORD=/tmp/notesequences.tfrecord
#
# convert_dir_to_note_sequences \
#   --input_dir=$INPUT_DIRECTORY \
#   --output_file=$SEQUENCES_TFRECORD \
#   --recursive
# Out:
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:Converting files in '/Users/hyojeongshin/test/data/'.
# I0124 00:20:01.469232 4348278272 convert_dir_to_note_sequences.py:83] Converting files in '/Users/hyojeongshin/test/data/'.
# INFO:tensorflow:0 files converted.
# I0124 00:20:01.470364 4348278272 convert_dir_to_note_sequences.py:89] 0 files converted.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/닮았대요.mxl.
# I0124 00:20:01.475975 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/닮았대요.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/아기염소.mxl.
# I0124 00:20:01.483983 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/아기염소.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/도깨비_나라.mxl.
# I0124 00:20:01.489106 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/도깨비_나라.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/안녕 김성균.mxl.
# I0124 00:20:01.493533 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/안녕 김성균.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/함박눈.mxl.
# I0124 00:20:01.496466 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/함박눈.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/그_얼마나_고마우냐.mxl.
# I0124 00:20:01.504595 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/그_얼마나_고마우냐.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/작은_동물원.mxl.
# I0124 00:20:01.508436 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/작은_동물원.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/사과같은_내_얼굴.mxl.
# I0124 00:20:01.511240 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/사과같은_내_얼굴.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/꼴찌를_위하여.mxl.
# I0124 00:20:01.519476 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/꼴찌를_위하여.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/그런_집_보았니.mxl.
# I0124 00:20:01.523909 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/그런_집_보았니.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/옹달샘.mxl.
# I0124 00:20:01.527022 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/옹달샘.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/여름_냇가.mxl.
# I0124 00:20:01.529827 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/여름_냇가.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/네잎_클로버.mxl.
# I0124 00:20:01.538213 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/네잎_클로버.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/머리_어깨_무릎_발.mxl.
# I0124 00:20:01.541307 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/머리_어깨_무릎_발.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/싹싹_닦아라.mxl.
# I0124 00:20:01.544584 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/싹싹_닦아라.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/라쿠카라차.mxl.
# I0124 00:20:01.548751 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/라쿠카라차.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/리듬악기_노래.mxl.
# I0124 00:20:01.552935 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/리듬악기_노래.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/내가_제일_좋아하는_말.mxl.
# I0124 00:20:01.558351 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/내가_제일_좋아하는_말.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/할아버지_시계.mxl.
# I0124 00:20:01.564197 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/할아버지_시계.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/이슬_열매.mxl.
# I0124 00:20:01.567914 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/이슬_열매.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/종이접기.mxl.
# I0124 00:20:01.572685 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/종이접기.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/기차를_타고.mxl.
# I0124 00:20:01.578222 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/기차를_타고.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/씨앗.mxl.
# I0124 00:20:01.581210 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/씨앗.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/겨울_바람.mxl.
# I0124 00:20:01.587162 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/겨울_바람.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/뚱보_아저씨.mxl.
# I0124 00:20:01.591062 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/뚱보_아저씨.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/숲_속_풍경.mxl.
# I0124 00:20:01.599930 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/숲_속_풍경.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/정글숲.mxl.
# I0124 00:20:01.602949 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/정글숲.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/산마루에서.mxl.
# I0124 00:20:01.607813 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/산마루에서.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/도토리.mxl.
# I0124 00:20:01.610864 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/도토리.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/통통통통.mxl.
# I0124 00:20:01.614680 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/통통통통.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/기린_미끄럼.mxl.
# I0124 00:20:01.617902 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/기린_미끄럼.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/아기별.mxl.
# I0124 00:20:01.620705 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/아기별.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/아기_다람쥐_또미.mxl.
# I0124 00:20:01.627557 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/아기_다람쥐_또미.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/나는_숲속의_음악가.mxl.
# I0124 00:20:01.632293 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/나는_숲속의_음악가.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/하늘나라_동화.mxl.
# I0124 00:20:01.636901 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/하늘나라_동화.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/누구하고_노나.mxl.
# I0124 00:20:01.639631 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/누구하고_노나.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/여름.mxl.
# I0124 00:20:01.642722 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/여름.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/개구리_노총각.mxl.
# I0124 00:20:01.648385 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/개구리_노총각.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/올챙이와_개구리.mxl.
# I0124 00:20:01.652667 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/올챙이와_개구리.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/선생님.mxl.
# I0124 00:20:01.657137 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/선생님.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/요기_여기.mxl.
# I0124 00:20:01.659893 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/요기_여기.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/에델바이스.mxl.
# I0124 00:20:01.664247 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/에델바이스.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/오솔길.mxl.
# I0124 00:20:01.675570 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/오솔길.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/꿀벌의_여행.mxl.
# I0124 00:20:01.778736 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/꿀벌의_여행.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/가위 바위 보.mxl.
# I0124 00:20:01.782533 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/가위 바위 보.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/수박_파티.mxl.
# I0124 00:20:01.787904 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/수박_파티.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/고향_땅.mxl.
# I0124 00:20:01.793236 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/고향_땅.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/어른이_되면.mxl.
# I0124 00:20:01.798763 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/어른이_되면.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/숲_속의_나라.mxl.
# I0124 00:20:01.801522 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/숲_속의_나라.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/가을_길.mxl.
# I0124 00:20:01.809324 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/가을_길.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/엄마_아빠_사랑해요.mxl.
# I0124 00:20:01.814618 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/엄마_아빠_사랑해요.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/참_좋은_우리집.mxl.
# I0124 00:20:01.819914 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/참_좋은_우리집.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/겨울_나무.mxl.
# I0124 00:20:01.824339 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/겨울_나무.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/허수아비_아저씨.mxl.
# I0124 00:20:01.827646 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/허수아비_아저씨.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/형님반에_간다네.mxl.
# I0124 00:20:01.831408 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/형님반에_간다네.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/숲속_초막집.mxl.
# I0124 00:20:01.835932 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/숲속_초막집.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/얼음_과자.mxl.
# I0124 00:20:01.840616 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/얼음_과자.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/저금통.mxl.
# I0124 00:20:01.843696 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/저금통.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/다락방.mxl.
# I0124 00:20:01.850142 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/다락방.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/마음이_이슬처럼.mxl.
# I0124 00:20:01.857311 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/마음이_이슬처럼.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/푸르다.mxl.
# I0124 00:20:01.860775 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/푸르다.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/여름방학.mxl.
# I0124 00:20:01.863995 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/여름방학.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/얼굴_찌푸리지_말아요.mxl.
# I0124 00:20:01.870193 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/얼굴_찌푸리지_말아요.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/코끼리_아저씨.mxl.
# I0124 00:20:01.875349 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/코끼리_아저씨.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/종달새의_하루.mxl.
# I0124 00:20:01.880036 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/종달새의_하루.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/하얀_나라.mxl.
# I0124 00:20:01.883674 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/하얀_나라.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/유리공주와_마귀할멈.mxl.
# I0124 00:20:01.888309 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/유리공주와_마귀할멈.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/돌과_물.mxl.
# I0124 00:20:01.892138 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/돌과_물.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/통통통.mxl.
# I0124 00:20:01.896209 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/통통통.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/산_너머_남촌에는.mxl.
# I0124 00:20:01.901175 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/산_너머_남촌에는.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/그림_그리고_싶은_날.mxl.
# I0124 00:20:01.905926 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/그림_그리고_싶은_날.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/세계의_아침인사.mxl.
# I0124 00:20:01.911502 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/세계의_아침인사.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/파란_가을_하늘.mxl.
# I0124 00:20:01.913973 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/파란_가을_하늘.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/봄비.mxl.
# I0124 00:20:01.917570 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/봄비.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/간다 간다.mxl.
# I0124 00:20:01.921258 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/간다 간다.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/우산속의_요정.mxl.
# I0124 00:20:01.927152 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/우산속의_요정.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/우리집은_동물원.mxl.
# I0124 00:20:01.936528 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/우리집은_동물원.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/괜찮아요.mxl.
# I0124 00:20:01.942006 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/괜찮아요.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/기차_놀이.mxl.
# I0124 00:20:01.944757 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/기차_놀이.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/초생달.mxl.
# I0124 00:20:01.949585 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/초생달.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/화가.mxl.
# I0124 00:20:01.954453 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/화가.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/아리랑.mxl.
# I0124 00:20:01.959450 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/아리랑.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/이_몸이_새라면.mxl.
# I0124 00:20:01.962655 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/이_몸이_새라면.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/예쁜_아기_곰.mxl.
# I0124 00:20:01.968269 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/예쁜_아기_곰.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/새싹들이다.mxl.
# I0124 00:20:01.973960 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/새싹들이다.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/건너가는_길.mxl.
# I0124 00:20:01.977848 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/건너가는_길.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/마법의_성.mxl.
# I0124 00:20:01.987013 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/마법의_성.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/강아지.mxl.
# I0124 00:20:01.990320 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/강아지.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/새들의_결혼식.mxl.
# I0124 00:20:01.993139 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/새들의_결혼식.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/미술시간.mxl.
# I0124 00:20:02.002160 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/미술시간.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/코끼리.mxl.
# I0124 00:20:02.004446 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/코끼리.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/꽃동네_새동네.mxl.
# I0124 00:20:02.013040 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/꽃동네_새동네.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/안녕.mxl.
# I0124 00:20:02.016138 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/안녕.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/어여쁜_친구.mxl.
# I0124 00:20:02.019547 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/어여쁜_친구.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/겨울밤.mxl.
# I0124 00:20:02.023158 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/겨울밤.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/솜사탕.mxl.
# I0124 00:20:02.026696 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/솜사탕.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/우리집.mxl.
# I0124 00:20:02.030753 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/우리집.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/즐거운_여름.mxl.
# I0124 00:20:02.034542 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/즐거운_여름.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/종이배.mxl.
# I0124 00:20:02.037360 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/종이배.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/로렐라이.mxl.
# I0124 00:20:02.042912 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/로렐라이.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/아가씨들아.mxl.
# I0124 00:20:02.049136 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/아가씨들아.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/아기_공룡_둘리.mxl.
# I0124 00:20:02.054955 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/아기_공룡_둘리.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/아빠_힘내세요.mxl.
# I0124 00:20:02.063872 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/아빠_힘내세요.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/그러면_안돼.mxl.
# I0124 00:20:02.069402 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/그러면_안돼.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/미소.mxl.
# I0124 00:20:02.074447 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/미소.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/어린_음악대.mxl.
# I0124 00:20:02.077387 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/어린_음악대.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/개구리_유치원.mxl.
# I0124 00:20:02.080991 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/개구리_유치원.mxl.
# INFO:tensorflow:Converted MusicXML file /Users/hyojeongshin/test/data/숲_속을_걸어요.mxl.
# I0124 00:20:02.085213 4348278272 convert_dir_to_note_sequences.py:180] Converted MusicXML file /Users/hyojeongshin/test/data/숲_속을_걸어요.mxl.

# %%
# %%bash
#
# source activate magenta
#
#
# improv_rnn_create_dataset \
# --config=chord_pitches_improv \
# --input=/tmp/notesequences.tfrecord \
# --output_dir=/tmp/improv_rnn/sequence_examples \
# --eval_ratio=0.10
# Out:
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/pipelines/pipeline.py:310: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0124 00:32:16.049157 4607849984 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/pipelines/pipeline.py:310: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:tensorflow:
#
# Completed.
#
# I0124 00:32:31.463863 4607849984 pipeline.py:386]
#
# Completed.
#
# INFO:tensorflow:Processed 108 inputs total. Produced 1140 outputs.
# I0124 00:32:31.463996 4607849984 pipeline.py:388] Processed 108 inputs total. Produced 1140 outputs.
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_coincident_chords: 0
# I0124 00:32:31.464072 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_coincident_chords: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_empty_chord_progressions: 0
# I0124 00:32:31.464130 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_empty_chord_progressions: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_melodies_discarded_too_few_pitches: 0
# I0124 00:32:31.464183 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_melodies_discarded_too_few_pitches: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_melodies_discarded_too_long: 0
# I0124 00:32:31.464236 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_melodies_discarded_too_long: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_melodies_discarded_too_short: 2
# I0124 00:32:31.464285 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_melodies_discarded_too_short: 2
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_melodies_truncated: 0
# I0124 00:32:31.464335 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_melodies_truncated: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_melody_lengths_in_bars:
#   [7,8): 4
#   [10,20): 5
#   [20,30): 1
#   [30,40): 1
# I0124 00:32:31.464398 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_melody_lengths_in_bars:
#   [7,8): 4
#   [10,20): 5
#   [20,30): 1
#   [30,40): 1
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_eval_polyphonic_tracks_discarded: 2
# I0124 00:32:31.464451 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_eval_polyphonic_tracks_discarded: 2
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_coincident_chords: 0
# I0124 00:32:31.464502 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_coincident_chords: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_empty_chord_progressions: 0
# I0124 00:32:31.464551 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_empty_chord_progressions: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_melodies_discarded_too_few_pitches: 0
# I0124 00:32:31.464601 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_melodies_discarded_too_few_pitches: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_melodies_discarded_too_long: 0
# I0124 00:32:31.464651 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_melodies_discarded_too_long: 0
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_melodies_discarded_too_short: 17
# I0124 00:32:31.464699 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_melodies_discarded_too_short: 17
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_melodies_truncated: 1
# I0124 00:32:31.464750 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_melodies_truncated: 1
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_melody_lengths_in_bars:
#   [7,8): 12
#   [8,10): 6
#   [10,20): 49
#   [20,30): 13
#   [30,40): 3
#   [40,50): 1
# I0124 00:32:31.464808 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_melody_lengths_in_bars:
#   [7,8): 12
#   [8,10): 6
#   [10,20): 49
#   [20,30): 13
#   [30,40): 3
#   [40,50): 1
# INFO:tensorflow:DAGPipeline_LeadSheetExtractor_training_polyphonic_tracks_discarded: 14
# I0124 00:32:31.464858 4607849984 statistics.py:137] DAGPipeline_LeadSheetExtractor_training_polyphonic_tracks_discarded: 14
# INFO:tensorflow:DAGPipeline_RandomPartition_eval_lead_sheets_count: 11
# I0124 00:32:31.464908 4607849984 statistics.py:137] DAGPipeline_RandomPartition_eval_lead_sheets_count: 11
# INFO:tensorflow:DAGPipeline_RandomPartition_training_lead_sheets_count: 97
# I0124 00:32:31.464955 4607849984 statistics.py:137] DAGPipeline_RandomPartition_training_lead_sheets_count: 97

# %%
# %%bash
#
# source activate magenta
#
# improv_rnn_train \
# --config=chord_pitches_improv \
# --run_dir=/tmp/improv_rnn/logdir/run1 \
# --sequence_example_file=/tmp/improv_rnn/sequence_examples/training_lead_sheets.tfrecord \
# --hparams="batch_size=64,rnn_layer_sizes=[64,64]" \
# --num_training_steps=500
# Out:
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:hparams = {'batch_size': 1, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 3, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# I0124 01:02:31.354609 4533634560 events_rnn_graph.py:96] hparams = {'batch_size': 1, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 3, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# INFO:tensorflow:Train dir: /tmp/improv_rnn/logdir/run1/train
# I0124 01:02:31.354757 4533634560 improv_rnn_train.py:85] Train dir: /tmp/improv_rnn/logdir/run1/train
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:66: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0124 01:02:31.355226 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:66: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0124 01:02:31.358819 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# W0124 01:02:31.359452 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0124 01:02:31.360605 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0124 01:02:31.361205 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:67: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# W0124 01:02:31.363642 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:67: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# INFO:tensorflow:Counting records in /tmp/improv_rnn/sequence_examples/training_lead_sheets.tfrecord.
# I0124 01:02:31.368986 4533634560 sequence_example_lib.py:121] Counting records in /tmp/improv_rnn/sequence_examples/training_lead_sheets.tfrecord.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:122: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0124 01:02:31.369072 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:122: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:tensorflow:Number of records is at least 100.
# I0124 01:02:31.378581 4533634560 sequence_example_lib.py:125] Number of records is at least 100.
# INFO:tensorflow:[<tf.Tensor 'random_shuffle_queue_Dequeue:0' shape=(?, 75) dtype=float32>, <tf.Tensor 'random_shuffle_queue_Dequeue:1' shape=(?,) dtype=int64>, <tf.Tensor 'random_shuffle_queue_Dequeue:2' shape=() dtype=int32>]
# I0124 01:02:31.382039 4533634560 sequence_example_lib.py:99] [<tf.Tensor 'random_shuffle_queue_Dequeue:0' shape=(?, 75) dtype=float32>, <tf.Tensor 'random_shuffle_queue_Dequeue:1' shape=(?,) dtype=int64>, <tf.Tensor 'random_shuffle_queue_Dequeue:2' shape=() dtype=int32>]
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:106: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# W0124 01:02:31.382202 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/common/sequence_example_lib.py:106: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:50: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = base_cell(rnn_layer_sizes[i])
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0124 01:02:31.401182 4533634560 rnn_cell_impl.py:1259] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:139: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0124 01:02:31.412149 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:139: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:756: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   shape=[input_depth + h_depth, 4 * self._num_units])
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:760: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0124 01:02:31.454745 4533634560 deprecation.py:551] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:760: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:760: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   initializer=tf.compat.v1.zeros_initializer(dtype=self.dtype))
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:173: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0124 01:02:31.532758 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:173: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:186: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0124 01:02:31.534595 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:186: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Starting training loop...
# I0124 01:02:31.847747 4533634560 events_rnn_train.py:103] Starting training loop...
# INFO:tensorflow:Create CheckpointSaverHook.
# I0124 01:02:31.847877 4533634560 basic_session_run_hooks.py:562] Create CheckpointSaverHook.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/training_util.py:401: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0124 01:02:31.936452 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/training_util.py:401: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Graph was finalized.
# I0124 01:02:31.986335 4533634560 monitored_session.py:247] Graph was finalized.
# 2022-01-24 01:02:31.986629: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from /tmp/improv_rnn/logdir/run1/train/model.ckpt-1500
# I0124 01:02:31.987950 4533634560 saver.py:1399] Restoring parameters from /tmp/improv_rnn/logdir/run1/train/model.ckpt-1500
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1165: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# W0124 01:02:32.023036 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1165: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# I0124 01:02:32.042134 4533634560 session_manager.py:531] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0124 01:02:32.047212 4533634560 session_manager.py:534] Done running local_init_op.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py:918: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0124 01:02:32.065469 4533634560 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py:918: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1500...
# I0124 01:02:32.452522 4533634560 basic_session_run_hooks.py:630] Calling checkpoint listeners before saving checkpoint 1500...
# INFO:tensorflow:Saving checkpoints for 1500 into /tmp/improv_rnn/logdir/run1/train/model.ckpt.
# I0124 01:02:32.452751 4533634560 basic_session_run_hooks.py:634] Saving checkpoints for 1500 into /tmp/improv_rnn/logdir/run1/train/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1500...
# I0124 01:02:32.524062 4533634560 basic_session_run_hooks.py:642] Calling checkpoint listeners after saving checkpoint 1500...
# INFO:tensorflow:Accuracy = 0.6989247, Global Step = 1501, Loss = 1.0672898, Perplexity = 2.907489
# I0124 01:02:32.740638 4533634560 basic_session_run_hooks.py:270] Accuracy = 0.6989247, Global Step = 1501, Loss = 1.0672898, Perplexity = 2.907489
# INFO:tensorflow:Accuracy = 0.73953485, Global Step = 1511, Loss = 0.9745192, Perplexity = 2.6498928 (0.581 sec)
# I0124 01:02:33.321818 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.73953485, Global Step = 1511, Loss = 0.9745192, Perplexity = 2.6498928 (0.581 sec)
# INFO:tensorflow:global_step/sec: 17.2072
# I0124 01:02:33.322235 4533634560 basic_session_run_hooks.py:718] global_step/sec: 17.2072
# INFO:tensorflow:Accuracy = 0.66754615, Global Step = 1521, Loss = 1.201859, Perplexity = 3.3262947 (0.384 sec)
# I0124 01:02:33.705883 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.66754615, Global Step = 1521, Loss = 1.201859, Perplexity = 3.3262947 (0.384 sec)
# INFO:tensorflow:global_step/sec: 26.0367
# I0124 01:02:33.706309 4533634560 basic_session_run_hooks.py:718] global_step/sec: 26.0367
# INFO:tensorflow:Accuracy = 0.6666667, Global Step = 1531, Loss = 1.2485181, Perplexity = 3.4851744 (0.373 sec)
# I0124 01:02:34.078661 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6666667, Global Step = 1531, Loss = 1.2485181, Perplexity = 3.4851744 (0.373 sec)
# INFO:tensorflow:global_step/sec: 26.8227
# I0124 01:02:34.079130 4533634560 basic_session_run_hooks.py:718] global_step/sec: 26.8227
# INFO:tensorflow:Accuracy = 0.7486631, Global Step = 1541, Loss = 0.9081921, Perplexity = 2.4798353 (0.291 sec)
# I0124 01:02:34.369889 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7486631, Global Step = 1541, Loss = 0.9081921, Perplexity = 2.4798353 (0.291 sec)
# INFO:tensorflow:global_step/sec: 34.3424
# I0124 01:02:34.370313 4533634560 basic_session_run_hooks.py:718] global_step/sec: 34.3424
# INFO:tensorflow:Accuracy = 0.7433155, Global Step = 1551, Loss = 0.8859098, Perplexity = 2.4251897 (0.414 sec)
# I0124 01:02:34.783706 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7433155, Global Step = 1551, Loss = 0.8859098, Perplexity = 2.4251897 (0.414 sec)
# INFO:tensorflow:global_step/sec: 24.1645
# I0124 01:02:34.784145 4533634560 basic_session_run_hooks.py:718] global_step/sec: 24.1645
# INFO:tensorflow:Accuracy = 0.6666667, Global Step = 1561, Loss = 1.0778803, Perplexity = 2.9384441 (0.339 sec)
# I0124 01:02:35.122768 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6666667, Global Step = 1561, Loss = 1.0778803, Perplexity = 2.9384441 (0.339 sec)
# INFO:tensorflow:global_step/sec: 29.4958
# I0124 01:02:35.123173 4533634560 basic_session_run_hooks.py:718] global_step/sec: 29.4958
# INFO:tensorflow:Accuracy = 0.6602871, Global Step = 1571, Loss = 1.153948, Perplexity = 3.170686 (0.383 sec)
# I0124 01:02:35.505795 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6602871, Global Step = 1571, Loss = 1.153948, Perplexity = 3.170686 (0.383 sec)
# INFO:tensorflow:global_step/sec: 26.1084
# I0124 01:02:35.506196 4533634560 basic_session_run_hooks.py:718] global_step/sec: 26.1084
# INFO:tensorflow:Accuracy = 0.67729086, Global Step = 1581, Loss = 1.0644139, Perplexity = 2.8991394 (0.269 sec)
# I0124 01:02:35.775031 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.67729086, Global Step = 1581, Loss = 1.0644139, Perplexity = 2.8991394 (0.269 sec)
# INFO:tensorflow:global_step/sec: 37.13
# I0124 01:02:35.775532 4533634560 basic_session_run_hooks.py:718] global_step/sec: 37.13
# INFO:tensorflow:Accuracy = 0.6062992, Global Step = 1591, Loss = 1.2983074, Perplexity = 3.6630914 (0.346 sec)
# I0124 01:02:36.121255 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6062992, Global Step = 1591, Loss = 1.2983074, Perplexity = 3.6630914 (0.346 sec)
# INFO:tensorflow:global_step/sec: 28.8805
# I0124 01:02:36.121779 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.8805
# INFO:tensorflow:global_step/sec: 27.0539
# I0124 01:02:36.436643 4533634560 basic_session_run_hooks.py:718] global_step/sec: 27.0539
# INFO:tensorflow:Accuracy = 0.6585366, Global Step = 1601, Loss = 1.0476763, Perplexity = 2.8510187 (0.316 sec)
# I0124 01:02:36.437080 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6585366, Global Step = 1601, Loss = 1.0476763, Perplexity = 2.8510187 (0.316 sec)
# INFO:tensorflow:global_step/sec: 31.6861
# I0124 01:02:36.437363 4533634560 basic_session_run_hooks.py:718] global_step/sec: 31.6861
# INFO:tensorflow:Accuracy = 0.64028776, Global Step = 1611, Loss = 1.0402603, Perplexity = 2.8299537 (0.354 sec)
# I0124 01:02:36.791556 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.64028776, Global Step = 1611, Loss = 1.0402603, Perplexity = 2.8299537 (0.354 sec)
# INFO:tensorflow:global_step/sec: 28.1969
# I0124 01:02:36.792016 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.1969
# INFO:tensorflow:Accuracy = 0.6975169, Global Step = 1621, Loss = 1.0501595, Perplexity = 2.8581069 (0.297 sec)
# I0124 01:02:37.088640 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6975169, Global Step = 1621, Loss = 1.0501595, Perplexity = 2.8581069 (0.297 sec)
# INFO:tensorflow:global_step/sec: 33.6647
# I0124 01:02:37.089069 4533634560 basic_session_run_hooks.py:718] global_step/sec: 33.6647
# INFO:tensorflow:Accuracy = 0.7387863, Global Step = 1631, Loss = 1.055271, Perplexity = 2.8727536 (0.509 sec)
# I0124 01:02:37.597142 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7387863, Global Step = 1631, Loss = 1.055271, Perplexity = 2.8727536 (0.509 sec)
# INFO:tensorflow:global_step/sec: 19.6663
# I0124 01:02:37.597548 4533634560 basic_session_run_hooks.py:718] global_step/sec: 19.6663
# INFO:tensorflow:Accuracy = 0.7096774, Global Step = 1641, Loss = 1.285361, Perplexity = 3.6159732 (0.352 sec)
# I0124 01:02:37.949597 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7096774, Global Step = 1641, Loss = 1.285361, Perplexity = 3.6159732 (0.352 sec)
# INFO:tensorflow:global_step/sec: 28.3702
# I0124 01:02:37.950027 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.3702
# INFO:tensorflow:Accuracy = 0.73350924, Global Step = 1651, Loss = 1.1476916, Perplexity = 3.1509109 (0.424 sec)
# I0124 01:02:38.374075 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.73350924, Global Step = 1651, Loss = 1.1476916, Perplexity = 3.1509109 (0.424 sec)
# INFO:tensorflow:global_step/sec: 23.5595
# I0124 01:02:38.374485 4533634560 basic_session_run_hooks.py:718] global_step/sec: 23.5595
# INFO:tensorflow:Accuracy = 0.66906476, Global Step = 1661, Loss = 1.0806167, Perplexity = 2.9464962 (0.413 sec)
# I0124 01:02:38.787471 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.66906476, Global Step = 1661, Loss = 1.0806167, Perplexity = 2.9464962 (0.413 sec)
# INFO:tensorflow:global_step/sec: 24.1868
# I0124 01:02:38.787935 4533634560 basic_session_run_hooks.py:718] global_step/sec: 24.1868
# INFO:tensorflow:Accuracy = 0.64444447, Global Step = 1671, Loss = 1.2591895, Perplexity = 3.5225651 (0.487 sec)
# I0124 01:02:39.274472 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.64444447, Global Step = 1671, Loss = 1.2591895, Perplexity = 3.5225651 (0.487 sec)
# INFO:tensorflow:global_step/sec: 20.5374
# I0124 01:02:39.274853 4533634560 basic_session_run_hooks.py:718] global_step/sec: 20.5374
# INFO:tensorflow:Accuracy = 0.73350924, Global Step = 1681, Loss = 1.1804092, Perplexity = 3.255706 (0.394 sec)
# I0124 01:02:39.668840 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.73350924, Global Step = 1681, Loss = 1.1804092, Perplexity = 3.255706 (0.394 sec)
# INFO:tensorflow:global_step/sec: 25.3538
# I0124 01:02:39.669270 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.3538
# INFO:tensorflow:Accuracy = 0.6352201, Global Step = 1691, Loss = 1.5896547, Perplexity = 4.9020557 (0.354 sec)
# I0124 01:02:40.022710 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6352201, Global Step = 1691, Loss = 1.5896547, Perplexity = 4.9020557 (0.354 sec)
# INFO:tensorflow:global_step/sec: 28.261
# I0124 01:02:40.023117 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.261
# INFO:tensorflow:global_step/sec: 25.0382
# I0124 01:02:40.430534 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.0382
# INFO:tensorflow:Accuracy = 0.677686, Global Step = 1701, Loss = 1.0956627, Perplexity = 2.9911642 (0.408 sec)
# I0124 01:02:40.431010 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.677686, Global Step = 1701, Loss = 1.0956627, Perplexity = 2.9911642 (0.408 sec)
# INFO:tensorflow:global_step/sec: 24.4991
# I0124 01:02:40.431288 4533634560 basic_session_run_hooks.py:718] global_step/sec: 24.4991
# INFO:tensorflow:Accuracy = 0.6243386, Global Step = 1711, Loss = 1.4118758, Perplexity = 4.103646 (0.438 sec)
# I0124 01:02:40.869493 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6243386, Global Step = 1711, Loss = 1.4118758, Perplexity = 4.103646 (0.438 sec)
# INFO:tensorflow:global_step/sec: 22.7961
# I0124 01:02:40.869969 4533634560 basic_session_run_hooks.py:718] global_step/sec: 22.7961
# INFO:tensorflow:Accuracy = 0.63779527, Global Step = 1721, Loss = 1.160463, Perplexity = 3.1914105 (0.392 sec)
# I0124 01:02:41.261466 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.63779527, Global Step = 1721, Loss = 1.160463, Perplexity = 3.1914105 (0.392 sec)
# INFO:tensorflow:global_step/sec: 25.517
# I0124 01:02:41.261860 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.517
# INFO:tensorflow:Accuracy = 0.6352201, Global Step = 1731, Loss = 1.5233532, Perplexity = 4.5875826 (0.394 sec)
# I0124 01:02:41.655477 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6352201, Global Step = 1731, Loss = 1.5233532, Perplexity = 4.5875826 (0.394 sec)
# INFO:tensorflow:global_step/sec: 25.3795
# I0124 01:02:41.655879 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.3795
# INFO:tensorflow:Accuracy = 0.6296296, Global Step = 1741, Loss = 1.3236396, Perplexity = 3.7570708 (0.386 sec)
# I0124 01:02:42.041675 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6296296, Global Step = 1741, Loss = 1.3236396, Perplexity = 3.7570708 (0.386 sec)
# INFO:tensorflow:global_step/sec: 25.8911
# I0124 01:02:42.042113 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.8911
# INFO:tensorflow:Accuracy = 0.7096774, Global Step = 1751, Loss = 1.2754214, Perplexity = 3.5802097 (0.299 sec)
# I0124 01:02:42.340933 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7096774, Global Step = 1751, Loss = 1.2754214, Perplexity = 3.5802097 (0.299 sec)
# INFO:tensorflow:global_step/sec: 33.4149
# I0124 01:02:42.341377 4533634560 basic_session_run_hooks.py:718] global_step/sec: 33.4149
# INFO:tensorflow:Accuracy = 0.7308707, Global Step = 1761, Loss = 0.9651258, Perplexity = 2.6251178 (0.417 sec)
# I0124 01:02:42.757889 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7308707, Global Step = 1761, Loss = 0.9651258, Perplexity = 2.6251178 (0.417 sec)
# INFO:tensorflow:global_step/sec: 23.987
# I0124 01:02:42.758274 4533634560 basic_session_run_hooks.py:718] global_step/sec: 23.987
# INFO:tensorflow:Accuracy = 0.64021164, Global Step = 1771, Loss = 1.2139909, Perplexity = 3.366895 (0.381 sec)
# I0124 01:02:43.138411 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.64021164, Global Step = 1771, Loss = 1.2139909, Perplexity = 3.366895 (0.381 sec)
# INFO:tensorflow:global_step/sec: 26.2719
# I0124 01:02:43.138910 4533634560 basic_session_run_hooks.py:718] global_step/sec: 26.2719
# INFO:tensorflow:Accuracy = 0.646438, Global Step = 1781, Loss = 1.2496465, Perplexity = 3.4891095 (0.424 sec)
# I0124 01:02:43.562508 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.646438, Global Step = 1781, Loss = 1.2496465, Perplexity = 3.4891095 (0.424 sec)
# INFO:tensorflow:global_step/sec: 23.582
# I0124 01:02:43.562958 4533634560 basic_session_run_hooks.py:718] global_step/sec: 23.582
# INFO:tensorflow:Accuracy = 0.7378641, Global Step = 1791, Loss = 0.93371457, Perplexity = 2.5439413 (0.341 sec)
# I0124 01:02:43.903447 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7378641, Global Step = 1791, Loss = 0.93371457, Perplexity = 2.5439413 (0.341 sec)
# INFO:tensorflow:global_step/sec: 29.3334
# I0124 01:02:43.903875 4533634560 basic_session_run_hooks.py:718] global_step/sec: 29.3334
# INFO:tensorflow:global_step/sec: 25.8291
# I0124 01:02:44.302134 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.8291
# INFO:tensorflow:Accuracy = 0.73170733, Global Step = 1801, Loss = 0.9409115, Perplexity = 2.562316 (0.399 sec)
# I0124 01:02:44.302607 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.73170733, Global Step = 1801, Loss = 0.9409115, Perplexity = 2.562316 (0.399 sec)
# INFO:tensorflow:global_step/sec: 25.0612
# I0124 01:02:44.302885 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.0612
# INFO:tensorflow:Accuracy = 0.689243, Global Step = 1811, Loss = 1.0919162, Perplexity = 2.9799788 (0.272 sec)
# I0124 01:02:44.574703 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.689243, Global Step = 1811, Loss = 1.0919162, Perplexity = 2.9799788 (0.272 sec)
# INFO:tensorflow:global_step/sec: 36.7301
# I0124 01:02:44.575149 4533634560 basic_session_run_hooks.py:718] global_step/sec: 36.7301
# INFO:tensorflow:Accuracy = 0.6535433, Global Step = 1821, Loss = 1.1250701, Perplexity = 3.0804327 (0.375 sec)
# I0124 01:02:44.949708 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6535433, Global Step = 1821, Loss = 1.1250701, Perplexity = 3.0804327 (0.375 sec)
# INFO:tensorflow:global_step/sec: 26.6681
# I0124 01:02:44.950134 4533634560 basic_session_run_hooks.py:718] global_step/sec: 26.6681
# INFO:tensorflow:Accuracy = 0.5473684, Global Step = 1831, Loss = 1.4125037, Perplexity = 4.1062236 (0.526 sec)
# I0124 01:02:45.476128 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.5473684, Global Step = 1831, Loss = 1.4125037, Perplexity = 4.1062236 (0.526 sec)
# INFO:tensorflow:global_step/sec: 18.996
# I0124 01:02:45.476577 4533634560 basic_session_run_hooks.py:718] global_step/sec: 18.996
# INFO:tensorflow:Accuracy = 0.72357726, Global Step = 1841, Loss = 0.9025869, Perplexity = 2.465974 (0.366 sec)
# I0124 01:02:45.842592 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.72357726, Global Step = 1841, Loss = 0.9025869, Perplexity = 2.465974 (0.366 sec)
# INFO:tensorflow:global_step/sec: 27.2836
# I0124 01:02:45.843101 4533634560 basic_session_run_hooks.py:718] global_step/sec: 27.2836
# INFO:tensorflow:Accuracy = 0.7479675, Global Step = 1851, Loss = 0.92790455, Perplexity = 2.529204 (0.349 sec)
# I0124 01:02:46.191354 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7479675, Global Step = 1851, Loss = 0.92790455, Perplexity = 2.529204 (0.349 sec)
# INFO:tensorflow:global_step/sec: 28.6783
# I0124 01:02:46.191770 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.6783
# INFO:tensorflow:Accuracy = 0.749004, Global Step = 1861, Loss = 0.8937278, Perplexity = 2.444224 (0.291 sec)
# I0124 01:02:46.482141 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.749004, Global Step = 1861, Loss = 0.8937278, Perplexity = 2.444224 (0.291 sec)
# INFO:tensorflow:global_step/sec: 34.3915
# I0124 01:02:46.482537 4533634560 basic_session_run_hooks.py:718] global_step/sec: 34.3915
# INFO:tensorflow:Accuracy = 0.61256546, Global Step = 1871, Loss = 1.4714838, Perplexity = 4.3556933 (0.346 sec)
# I0124 01:02:46.828366 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.61256546, Global Step = 1871, Loss = 1.4714838, Perplexity = 4.3556933 (0.346 sec)
# INFO:tensorflow:global_step/sec: 28.8828
# I0124 01:02:46.828764 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.8828
# INFO:tensorflow:Accuracy = 0.6230366, Global Step = 1881, Loss = 1.3766129, Perplexity = 3.961461 (0.337 sec)
# I0124 01:02:47.165274 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6230366, Global Step = 1881, Loss = 1.3766129, Perplexity = 3.961461 (0.337 sec)
# INFO:tensorflow:global_step/sec: 29.6783
# I0124 01:02:47.165712 4533634560 basic_session_run_hooks.py:718] global_step/sec: 29.6783
# INFO:tensorflow:Accuracy = 0.64748204, Global Step = 1891, Loss = 0.99803555, Perplexity = 2.7129471 (0.315 sec)
# I0124 01:02:47.480653 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.64748204, Global Step = 1891, Loss = 0.99803555, Perplexity = 2.7129471 (0.315 sec)
# INFO:tensorflow:global_step/sec: 31.7103
# I0124 01:02:47.481068 4533634560 basic_session_run_hooks.py:718] global_step/sec: 31.7103
# INFO:tensorflow:global_step/sec: 28.0648
# I0124 01:02:47.865320 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.0648
# INFO:tensorflow:Accuracy = 0.5873016, Global Step = 1901, Loss = 1.0183924, Perplexity = 2.7687402 (0.385 sec)
# I0124 01:02:47.865748 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.5873016, Global Step = 1901, Loss = 1.0183924, Perplexity = 2.7687402 (0.385 sec)
# INFO:tensorflow:global_step/sec: 25.9767
# I0124 01:02:47.866024 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.9767
# INFO:tensorflow:Accuracy = 0.7479675, Global Step = 1911, Loss = 0.9338964, Perplexity = 2.544404 (0.430 sec)
# I0124 01:02:48.296259 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7479675, Global Step = 1911, Loss = 0.9338964, Perplexity = 2.544404 (0.430 sec)
# INFO:tensorflow:global_step/sec: 23.2159
# I0124 01:02:48.296777 4533634560 basic_session_run_hooks.py:718] global_step/sec: 23.2159
# INFO:tensorflow:Accuracy = 0.6893204, Global Step = 1921, Loss = 0.95421696, Perplexity = 2.5966365 (0.357 sec)
# I0124 01:02:48.652922 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6893204, Global Step = 1921, Loss = 0.95421696, Perplexity = 2.5966365 (0.357 sec)
# INFO:tensorflow:global_step/sec: 28.0437
# I0124 01:02:48.653355 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.0437
# INFO:tensorflow:Accuracy = 0.6906475, Global Step = 1931, Loss = 1.075474, Perplexity = 2.9313822 (0.358 sec)
# I0124 01:02:49.011181 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6906475, Global Step = 1931, Loss = 1.075474, Perplexity = 2.9313822 (0.358 sec)
# INFO:tensorflow:global_step/sec: 27.9156
# I0124 01:02:49.011580 4533634560 basic_session_run_hooks.py:718] global_step/sec: 27.9156
# INFO:tensorflow:Accuracy = 0.7450199, Global Step = 1941, Loss = 0.922237, Perplexity = 2.51491 (0.331 sec)
# I0124 01:02:49.342023 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7450199, Global Step = 1941, Loss = 0.922237, Perplexity = 2.51491 (0.331 sec)
# INFO:tensorflow:global_step/sec: 30.2143
# I0124 01:02:49.342551 4533634560 basic_session_run_hooks.py:718] global_step/sec: 30.2143
# INFO:tensorflow:Accuracy = 0.76095617, Global Step = 1951, Loss = 0.8100651, Perplexity = 2.2480543 (0.382 sec)
# I0124 01:02:49.724212 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.76095617, Global Step = 1951, Loss = 0.8100651, Perplexity = 2.2480543 (0.382 sec)
# INFO:tensorflow:global_step/sec: 26.174
# I0124 01:02:49.724602 4533634560 basic_session_run_hooks.py:718] global_step/sec: 26.174
# INFO:tensorflow:Accuracy = 0.7689243, Global Step = 1961, Loss = 0.85274655, Perplexity = 2.3460817 (0.352 sec)
# I0124 01:02:50.075948 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7689243, Global Step = 1961, Loss = 0.85274655, Perplexity = 2.3460817 (0.352 sec)
# INFO:tensorflow:global_step/sec: 28.4153
# I0124 01:02:50.076555 4533634560 basic_session_run_hooks.py:718] global_step/sec: 28.4153
# INFO:tensorflow:Accuracy = 0.6296296, Global Step = 1971, Loss = 1.2150285, Perplexity = 3.3703902 (0.298 sec)
# I0124 01:02:50.374114 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.6296296, Global Step = 1971, Loss = 1.2150285, Perplexity = 3.3703902 (0.298 sec)
# INFO:tensorflow:global_step/sec: 33.5582
# I0124 01:02:50.374516 4533634560 basic_session_run_hooks.py:718] global_step/sec: 33.5582
# INFO:tensorflow:Accuracy = 0.7255937, Global Step = 1981, Loss = 1.1265525, Perplexity = 3.0850024 (0.394 sec)
# I0124 01:02:50.767818 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.7255937, Global Step = 1981, Loss = 1.1265525, Perplexity = 3.0850024 (0.394 sec)
# INFO:tensorflow:global_step/sec: 25.4001
# I0124 01:02:50.768216 4533634560 basic_session_run_hooks.py:718] global_step/sec: 25.4001
# INFO:tensorflow:Accuracy = 0.749004, Global Step = 1991, Loss = 0.8746195, Perplexity = 2.3979626 (0.367 sec)
# I0124 01:02:51.134890 4533634560 basic_session_run_hooks.py:268] Accuracy = 0.749004, Global Step = 1991, Loss = 0.8746195, Perplexity = 2.3979626 (0.367 sec)
# INFO:tensorflow:global_step/sec: 27.2421
# I0124 01:02:51.135293 4533634560 basic_session_run_hooks.py:718] global_step/sec: 27.2421
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2000...
# I0124 01:02:51.549411 4533634560 basic_session_run_hooks.py:630] Calling checkpoint listeners before saving checkpoint 2000...
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/improv_rnn/logdir/run1/train/model.ckpt.
# I0124 01:02:51.549524 4533634560 basic_session_run_hooks.py:634] Saving checkpoints for 2000 into /tmp/improv_rnn/logdir/run1/train/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2000...
# I0124 01:02:51.603705 4533634560 basic_session_run_hooks.py:642] Calling checkpoint listeners after saving checkpoint 2000...
# INFO:tensorflow:Training complete.
# I0124 01:02:51.638543 4533634560 events_rnn_train.py:113] Training complete.

# %%
# %%bash
#
# source activate magenta
#
# improv_rnn_train \
# --config=chord_pitches_improv \
# --run_dir=/tmp/improv_rnn/logdir/run1 \
# --sequence_example_file=/tmp/improv_rnn/sequence_examples/eval_lead_sheets.tfrecord \
# --hparams="{'batch_size':1,'rnn_layer_sizes':[64,64]}" \
# --num_training_steps=500 \
# --eval
# Out:
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Traceback (most recent call last):
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/bin/improv_rnn_train", line 8, in <module>
#     sys.exit(console_entry_point())
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/improv_rnn/improv_rnn_train.py", line 106, in console_entry_point
#     tf.app.run(main)
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/absl/app.py", line 312, in run
#     _run_main(main, args)
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/absl/app.py", line 258, in _run_main
#     sys.exit(main(argv))
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/improv_rnn/improv_rnn_train.py", line 77, in main
#     config = improv_rnn_config_flags.config_from_flags()
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/improv_rnn/improv_rnn_config_flags.py", line 59, in config_from_flags
#     config.hparams.parse(FLAGS.hparams)
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensor2tensor/utils/hparam.py", line 503, in parse
#     values_map = parse_values(values, type_map)
#   File "/Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensor2tensor/utils/hparam.py", line 255, in parse_values
#     raise ValueError('Malformed hyperparameter value: %s' % values[pos:])
# ValueError: Malformed hyperparameter value: {'batch_size':1,'rnn_layer_sizes':[64,64]}
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /var/folders/5t/2rcr0fq92879s1tk0gx717l00000gn/T/ipykernel_11294/2148274828.py in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nsource activate magenta\n\nimprov_rnn_train \\\n--config=chord_pitches_improv \\\n--run_dir=/tmp/improv_rnn/logdir/run1 \\\n--sequence_example_file=/tmp/improv_rnn/sequence_examples/eval_lead_sheets.tfrecord \\\n--hparams="{\'batch_size\':1,\'rnn_layer_sizes\':[64,64]}" \\\n--num_training_steps=500 \\\n--eval\n')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             with self.builtin_trap:
#    2405                 args = (magic_arg_s, cell)
# -> 2406                 result = fn(*args, **kwargs)
#    2407             return result
#    2408
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nsource activate magenta\n\nimprov_rnn_train \\\n--config=chord_pitches_improv \\\n--run_dir=/tmp/improv_rnn/logdir/run1 \\\n--sequence_example_file=/tmp/improv_rnn/sequence_examples/eval_lead_sheets.tfrecord \\\n--hparams="{\'batch_size\':1,\'rnn_layer_sizes\':[64,64]}" \\\n--num_training_steps=500 \\\n--eval\n'' returned non-zero exit status 1.

# %%
# %%bash
#
# source activate magenta
#
# tensorboard --logdir=/tmp/improv_rnn/logdir
#
# # http://localhost:6006/ 로 들어가서 확인
# Out:
# Process is terminated.

# %%
# %%bash
#
# source activate magenta
#
# improv_rnn_generate \
# --config=chord_pitches_improv \
# --run_dir=/tmp/improv_rnn/logdir/run1 \
# --hparams="batch_size=64,rnn_layer_sizes=[64,64]" \
# --bundle_file=/tmp/improv_rnn.mag \
# --save_generator_bundle
# Out:
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:No bundle description provided.
# W0124 01:17:52.542050 4745336320 improv_rnn_generate.py:278] No bundle description provided.
# INFO:tensorflow:Saving generator bundle to /tmp/improv_rnn.mag
# I0124 01:17:52.542134 4745336320 improv_rnn_generate.py:279] Saving generator bundle to /tmp/improv_rnn.mag
# WARNING:tensorflow:Writing bundle file with no bundle description.
# W0124 01:17:52.542298 4745336320 sequence_generator.py:219] Writing bundle file with no bundle description.
# INFO:tensorflow:hparams = {'batch_size': 1, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 3, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# I0124 01:17:52.543473 4745336320 events_rnn_graph.py:96] hparams = {'batch_size': 1, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 3, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:50: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = base_cell(rnn_layer_sizes[i])
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# W0124 01:17:52.558037 4745336320 rnn_cell_impl.py:1259] `tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:139: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0124 01:17:52.569850 4745336320 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:139: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:756: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   shape=[input_depth + h_depth, 4 * self._num_units])
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:760: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0124 01:17:52.607671 4745336320 deprecation.py:551] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:760: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:760: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   initializer=tf.compat.v1.zeros_initializer(dtype=self.dtype))
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:253: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0124 01:17:52.657926 4745336320 deprecation.py:347] From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/magenta/models/shared/events_rnn_graph.py:253: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# 2022-01-24 01:17:52.666074: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Checkpoint used: /tmp/improv_rnn/logdir/run1/train/model.ckpt-2000
# I0124 01:17:52.667440 4745336320 model.py:57] Checkpoint used: /tmp/improv_rnn/logdir/run1/train/model.ckpt-2000
# INFO:tensorflow:Restoring parameters from /tmp/improv_rnn/logdir/run1/train/model.ckpt-2000
# I0124 01:17:52.667592 4745336320 saver.py:1399] Restoring parameters from /tmp/improv_rnn/logdir/run1/train/model.ckpt-2000
# WARNING:tensorflow:*******************************************************
# W0124 01:17:52.688457 4745336320 saver.py:1238] *******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# W0124 01:17:52.688568 4745336320 saver.py:1239] TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# W0124 01:17:52.688624 4745336320 saver.py:1240] Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# W0124 01:17:52.688676 4745336320 saver.py:1241]    `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# W0124 01:17:52.688724 4745336320 saver.py:1242] now on by default.
# WARNING:tensorflow:*******************************************************
# W0124 01:17:52.688772 4745336320 saver.py:1243] *******************************************************

# %%
# %%bash
#
# source activate magenta
#
#
# improv_rnn_generate \
# --config=chord_pitches_improv \
# --bundle_file=/tmp/improv_rnn.mag \
# --output_dir=/tmp/improv_rnn/generated \
# --num_outputs=10 \
# --primer_melody="[60]" \
# --backing_chords="C G Am F C G Am F" \
# --render_chords
# Out:
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From /Users/hyojeongshin/opt/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2022-01-24 01:21:11.029370: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from /var/folders/5t/2rcr0fq92879s1tk0gx717l00000gn/T/tmpykly52hv/model.ckpt
# I0124 01:21:11.069038 4479673856 saver.py:1399] Restoring parameters from /var/folders/5t/2rcr0fq92879s1tk0gx717l00000gn/T/tmpykly52hv/model.ckpt
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -134.513199
# I0124 01:21:11.251354 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -134.513199
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -139.911652
# I0124 01:21:11.365438 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -139.911652
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -140.047623
# I0124 01:21:11.472200 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -140.047623
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -139.136551
# I0124 01:21:11.577645 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -139.136551
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -139.881302
# I0124 01:21:11.678661 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -139.881302
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -130.823563
# I0124 01:21:11.794975 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -130.823563
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -121.045555
# I0124 01:21:11.911229 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -121.045555
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -138.078812
# I0124 01:21:12.032816 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -138.078812
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -112.247482
# I0124 01:21:12.142771 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -112.247482
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -132.159576
# I0124 01:21:12.240391 4479673856 events_rnn_model.py:381] Beam search yields sequence with log-likelihood: -132.159576
# INFO:tensorflow:Wrote 10 MIDI files to /tmp/improv_rnn/generated
# I0124 01:21:12.245189 4479673856 improv_rnn_generate.py:249] Wrote 10 MIDI files to /tmp/improv_rnn/generated
